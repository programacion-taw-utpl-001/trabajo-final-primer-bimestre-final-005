# %%
import pandas as pd

# %%
datas = pd.read_csv('camas_2016.csv',sep=';', engine = 'python')
datas
# Out:
#      prov_ubie  cant_ubie  parr_ubie  clase  tipo  entidad  sector dotmedic  \
# 0            9        901      90150     12     3       18       2        2
# 1            1        103      10350      1     5        1       1        9
# 2            1        105      10550      1     5        1       1       10
# 3            1        108      10850      1     5        1       1        6
# 4            1        109      10950      1     5        1       1        8
# 5            1        101      10107      2     1        1       1       61
# 6            1        101      10150      7     2        1       1        0
# 7            1        102      10250      1     5        1       1        6
# 8            1        101      10150      2     1        6       1       14
# 9            1        101      10150      2     1        3       1       14
# 10           1        101      10150      8     2       15       3        0
# ...

# %%
data = pd.read_csv('camas_2016_2.csv',engine = 'python')
data
# Out:
#     PROVINCIA_ESTABLECIMIENTO    CANTO_ESTABLECIMIENTO  PARROQUIA_UBICACION  \
# 0                      Guayas                Guayaquil                90150
# 1                       Azuay                 Gualaceo                10350
# 2                       Azuay                    Paute                10550
# 3                       Azuay             Santa Isabel                10850
# 4                       Azuay                   Sigsig                10950
# 5                       Azuay                   Cuenca                10107
# 6                       Azuay                   Cuenca                10150
# 7                       Azuay                    Giron                10250
# 8                       Azuay                   Cuenca                10150
# 9                       Azuay                   Cuenca                10150
# 10                      Azuay                   Cuenca                10150
# ...

# %%
data.columns
# Out:
# Index(['PROVINCIA_ESTABLECIMIENTO', 'CANTO_ESTABLECIMIENTO',
#        'PARROQUIA_UBICACION', 'CLASE_ESTABLECIMIENTO', 'TIPO_ESTABLECIMIENTO',
#        'ENTIDAD', 'SECTOR', 'MEDICINA', 'CIRUGIA', 'GINECOLOGIA_OBSTETRICIA',
#        'PEDIATRIA', 'CARDIOLOGIA', 'NEUMOLOGIA', 'PSIQUIATRIA',
#        'TRAUMATOLOGIA', 'INFECTOLOGIA', 'OFTALMOLOGIA_OTORRINO', 'UROLOGIA',
#        'GASTROENTEROLOGIA', 'OTROS_SERVICIOS', 'SERVICIOS_INDIFERENCIADOS',
#        'CAMAS_EMERGENCIA', 'CAMAS_CUIDADOS_INTENSIVOS',
#        'CAMAS_DISPONIBLES_MEDICINA', 'CAMAS_DISPONIBLES_CIRUGIA',
#        'CAMAS_DISPONIBLES_GINECOLOGIA', 'CAMAS_DISPONIBLE_PEDIATRIA',
#        'CAMAS_DISPONIBLES_CARDIOLOGIA', 'CAMAS_DISPONIBLES_NEUMOLOGIA',
#        'CAMAS_DISPONIBLE_PSIQUIATRIA', 'CAMAS_DISPONIBLE_TRAUMOLOGIA',
#        'CAMAS_DISPONIBLES_INFECTOLOGIA', 'CAMAS_DISPONIBLES_OFTALMOLOGIA',
#        'CAMAS_DISPONIBLES_UROLOGIA', 'CAMAS_DISPONIBLES_GASTROENTEROLOGIA',
#        'CAMAS_DISPONIBLES_OTROS_SERVICIOS',
# ...
